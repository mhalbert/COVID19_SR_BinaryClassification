# %% [markdown]
# ## IMPORTS

# %%
import cv2
import numpy as np
import pandas as pd
SEED =12
def load_labels(label_file):
    """Loads image filenames, classes, and bounding boxes"""
    fnames, classes, bboxes = [], [], []
    with open(label_file, 'r') as f:
        for line in f.readlines():
            fname, cls, xmin, ymin, xmax, ymax = line.strip('\n').split()
            fnames.append(fname)
            classes.append(int(cls))
            bboxes.append((int(xmin), int(ymin), int(xmax), int(ymax)))
    fnames = ["/kaggle/input/covidxct/3A_images/" + fname for fname in fnames]
    fnames = np.array(fnames)
    classes = np.array(classes)
    return fnames, classes, bboxes

def index_generator(fnames , SET):
    """Genrated random index of a particular class"""
    np.random.seed(SEED)
    index = np.random.randint(1,len(fnames),size = SET)
    return index 

def numberofclasses(classes, index):
    class0 = len((np.where(classes[index]==0))[0])
    class1 = len((np.where(classes[index]==1))[0])
    class2 = len((np.where(classes[index]==2))[0])
    return class0  , class1, class2
def dataframe_generator(train_index , valid_index , classes_train , classes_valid ):
    """Returns 1 dataframes of datasets distribution"""
    index = ["Normal" , "Pneumonia" , "COIVD -19"]
    train_DF = numberofclasses(classes_train, train_index)
    valid_DF = numberofclasses(classes_valid, valid_index)
    df = pd.DataFrame({'train': train_DF ,'valid' : valid_DF} , index = index)
    return df
def train_index_updater(classes_train , train_index,n ):
    """Updates train_index for class balance"""
    np.random.seed(SEED)
    class0_train = np.where(classes_train[train_index]==0)[0]
    class1_train = np.where(classes_train[train_index]==1)[0]
    class2_train = np.where(classes_train[train_index]==2)[0]
    class0 =train_index[class0_train]
    class1 = train_index[class1_train]
    np.random.seed(SEED)
    class22 = np.random.choice(class2_train , n)
    class2 = train_index[class22]
    train_index_updated = np.concatenate((class0 , class1 , class2))
    np.random.shuffle(train_index_updated)
    return train_index_updated

def data_constructor(filepath, classes , dim_size ,index  ,bboxes , interpolation = cv2.INTER_AREA , intensify =False):
    """Constructs and splits X and Y for training , validtion and test"""
    np.random.seed(SEED)
    y = np.array(classes[index])
    x = []
    for i in index:
        img  = cv2.imread(filepath[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        x1,y1,x2,y2 = bboxes[i]
        img = img[y1:y2,x1:x2]
        img = cv2.resize(img, dim_size , interpolation = interpolation)
        # add SR step here
        x.append(img)
    
    x = np.array(x)
    if intensify == True:
        x= x/255
    return x , y

# %%
import tensorflow as tf
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import seaborn as sns
sns.set(style = "darkgrid")

# %% [markdown]
# ## SETTING UP PARAMETERS AND DIRECTORIES

# %%
SEED = 12
IMG_HEIGHT = 128
IMG_WIDTH = 128
DIM = (IMG_HEIGHT, IMG_WIDTH)
TRAIN_SET= 46778
VALID_SET= 6486
EPOCHS = 40
BS = 32
n = 8000
LR = 0.0001
label_file_train = "/kaggle/input/covidxct/train_COVIDx_CT-3A.txt"
label_file_valid = "/kaggle/input/covidxct/val_COVIDx_CT-3A.txt"

# %% [markdown]
# ## LOADING DATA

# %%
fnames_train, classes_train, bboxes_train = load_labels(label_file_train)
fnames_valid, classes_valid, bboxes_valid = load_labels(label_file_valid)
train_index = index_generator(fnames_train, TRAIN_SET)
valid_index = index_generator(fnames_valid, VALID_SET)
train_index_updated = train_index_updater(classes_train,train_index, n)
df = dataframe_generator(train_index_updated, valid_index, classes_train, classes_valid)
df.plot.bar(title = "Image Distribution");

# %% [markdown]
# ## Loading Training and Validation Images

# %%
x_train, y_train = data_constructor(fnames_train, classes_train, DIM, index=train_index_updated, bboxes = bboxes_train)
x_valid , y_valid= data_constructor(fnames_valid, classes_valid, DIM, index=valid_index, bboxes = bboxes_valid)

# %% [markdown]
# ## Pre-Processing

# %%
x_train = tf.keras.applications.densenet.preprocess_input(x_train)
x_valid = tf.keras.applications.densenet.preprocess_input(x_valid)

# %%
for i in range(len(y_train)):
    if y_train[i] ==1:
        y_train[i]=0
    if y_train[i] ==2:
        y_train[i]=1
for i in range(len(y_valid)):
    if y_valid[i] ==1:
        y_valid[i]=0
    if y_valid[i]==2:
        y_valid[i]=1

# %%
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=True,zoom_range=0.05,width_shift_range=0.2 ,height_shift_range=0.1,shear_range=0.05)## ENTER YOUR AUG HERE
train_generator = data_generator.flow(x_train, y_train, BS)
spe = x_train.shape[0] // BS

# %% [markdown]
# ## MODEL DESIGN

# %%
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout

# %%
base_model = DenseNet201(include_top=False,weights="imagenet",input_shape=(IMG_HEIGHT,IMG_HEIGHT,3))
model= tf.keras.Sequential()
model.add(base_model) 
model.add(GlobalAveragePooling2D())
model.add(Dense(64,activation=('relu'))) 
model.add(Dropout(.2))
model.add(Dense(1,activation=('sigmoid')))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 2s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 4, 4, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                122944
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 18,444,993
# Trainable params: 18,215,937
# Non-trainable params: 229,056
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(LR),
              loss = "binary_crossentropy",
              metrics = ["accuracy"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
modelsdir = "models"
checkpoint = ModelCheckpoint(filepath = modelsdir + "/SGD.{epoch:02d}-{val_accuracy:.4f}.h5" ,
                             monitor= "val_accuracy" , 
                             mode = "max",
                            verbose = 0,
                            save_best_only=True)

# %%
r = model.fit(train_generator , validation_data=(x_valid, y_valid), steps_per_epoch = spe ,epochs=EPOCHS, callbacks = [checkpoint])
# Out:
# Epoch 1/40
# 507/507 [==============================] - 199s 265ms/step - loss: 0.6677 - accuracy: 0.6040 - val_loss: 0.6923 - val_accuracy: 0.5811
# Epoch 2/40
# 507/507 [==============================] - 137s 270ms/step - loss: 0.5462 - accuracy: 0.7286 - val_loss: 0.5920 - val_accuracy: 0.6792
# Epoch 3/40
# 507/507 [==============================] - 127s 250ms/step - loss: 0.4644 - accuracy: 0.7956 - val_loss: 0.5702 - val_accuracy: 0.7027
# Epoch 4/40
# 507/507 [==============================] - 138s 271ms/step - loss: 0.4190 - accuracy: 0.8244 - val_loss: 0.5609 - val_accuracy: 0.7160
# Epoch 5/40
# 507/507 [==============================] - 127s 250ms/step - loss: 0.3824 - accuracy: 0.8450 - val_loss: 0.5023 - val_accuracy: 0.7566
# Epoch 6/40
# 507/507 [==============================] - 126s 249ms/step - loss: 0.3495 - accuracy: 0.8599 - val_loss: 0.5136 - val_accuracy: 0.7495
# Epoch 7/40
# 507/507 [==============================] - 127s 250ms/step - loss: 0.3300 - accuracy: 0.8690 - val_loss: 0.4980 - val_accuracy: 0.7633
# Epoch 8/40
# 507/507 [==============================] - 139s 274ms/step - loss: 0.3150 - accuracy: 0.8757 - val_loss: 0.4681 - val_accuracy: 0.7738
# Epoch 9/40
# 507/507 [==============================] - 137s 269ms/step - loss: 0.2936 - accuracy: 0.8841 - val_loss: 0.4477 - val_accuracy: 0.7956
# Epoch 10/40
# 507/507 [==============================] - 125s 247ms/step - loss: 0.2768 - accuracy: 0.8943 - val_loss: 0.4665 - val_accuracy: 0.7832
# Epoch 11/40
# 507/507 [==============================] - 135s 267ms/step - loss: 0.2652 - accuracy: 0.8968 - val_loss: 0.4030 - val_accuracy: 0.8188
# Epoch 12/40
# 507/507 [==============================] - 135s 266ms/step - loss: 0.2594 - accuracy: 0.9019 - val_loss: 0.4349 - val_accuracy: 0.8023
# Epoch 13/40
# 507/507 [==============================] - 124s 244ms/step - loss: 0.2456 - accuracy: 0.9054 - val_loss: 0.4117 - val_accuracy: 0.8128
# Epoch 14/40
# 507/507 [==============================] - 126s 247ms/step - loss: 0.2316 - accuracy: 0.9106 - val_loss: 0.3965 - val_accuracy: 0.8208
# Epoch 15/40
# 507/507 [==============================] - 126s 248ms/step - loss: 0.2244 - accuracy: 0.9138 - val_loss: 0.3951 - val_accuracy: 0.8242
# Epoch 16/40
# 507/507 [==============================] - 126s 247ms/step - loss: 0.2276 - accuracy: 0.9119 - val_loss: 0.3903 - val_accuracy: 0.8276
# Epoch 17/40
# 507/507 [==============================] - 124s 244ms/step - loss: 0.2143 - accuracy: 0.9189 - val_loss: 0.4034 - val_accuracy: 0.8162
# Epoch 18/40
# 507/507 [==============================] - 126s 247ms/step - loss: 0.2095 - accuracy: 0.9202 - val_loss: 0.3849 - val_accuracy: 0.8302
# Epoch 19/40
# 507/507 [==============================] - 137s 270ms/step - loss: 0.2064 - accuracy: 0.9220 - val_loss: 0.3679 - val_accuracy: 0.8414
# Epoch 20/40
# 507/507 [==============================] - 133s 262ms/step - loss: 0.2011 - accuracy: 0.9217 - val_loss: 0.3798 - val_accuracy: 0.8330
# Epoch 21/40
# 507/507 [==============================] - 134s 264ms/step - loss: 0.1946 - accuracy: 0.9268 - val_loss: 0.3797 - val_accuracy: 0.8333
# Epoch 22/40
# 507/507 [==============================] - 124s 243ms/step - loss: 0.1896 - accuracy: 0.9277 - val_loss: 0.3791 - val_accuracy: 0.8346
# Epoch 23/40
# 507/507 [==============================] - 133s 263ms/step - loss: 0.1921 - accuracy: 0.9268 - val_loss: 0.3764 - val_accuracy: 0.8375
# Epoch 24/40
# 507/507 [==============================] - 126s 249ms/step - loss: 0.1873 - accuracy: 0.9284 - val_loss: 0.3635 - val_accuracy: 0.8451
# Epoch 25/40
# 507/507 [==============================] - 125s 246ms/step - loss: 0.1866 - accuracy: 0.9296 - val_loss: 0.3839 - val_accuracy: 0.8349
# Epoch 26/40
# 507/507 [==============================] - 135s 266ms/step - loss: 0.1752 - accuracy: 0.9343 - val_loss: 0.3980 - val_accuracy: 0.8301
# Epoch 27/40
# 507/507 [==============================] - 135s 266ms/step - loss: 0.1730 - accuracy: 0.9325 - val_loss: 0.3938 - val_accuracy: 0.8340
# Epoch 28/40
# 507/507 [==============================] - 135s 266ms/step - loss: 0.1703 - accuracy: 0.9360 - val_loss: 0.3824 - val_accuracy: 0.8375
# Epoch 29/40
# 507/507 [==============================] - 124s 245ms/step - loss: 0.1689 - accuracy: 0.9379 - val_loss: 0.3855 - val_accuracy: 0.8363
# Epoch 30/40
# 507/507 [==============================] - 134s 264ms/step - loss: 0.1625 - accuracy: 0.9380 - val_loss: 0.4079 - val_accuracy: 0.8309
# Epoch 31/40
# 507/507 [==============================] - 135s 265ms/step - loss: 0.1604 - accuracy: 0.9390 - val_loss: 0.3935 - val_accuracy: 0.8377
# Epoch 32/40
# 507/507 [==============================] - 124s 245ms/step - loss: 0.1602 - accuracy: 0.9402 - val_loss: 0.4152 - val_accuracy: 0.8302
# Epoch 33/40
# 507/507 [==============================] - 134s 265ms/step - loss: 0.1565 - accuracy: 0.9409 - val_loss: 0.4151 - val_accuracy: 0.8318
# Epoch 34/40
# 507/507 [==============================] - 124s 245ms/step - loss: 0.1625 - accuracy: 0.9368 - val_loss: 0.3874 - val_accuracy: 0.8397
# Epoch 35/40
# 507/507 [==============================] - 124s 245ms/step - loss: 0.1570 - accuracy: 0.9393 - val_loss: 0.4095 - val_accuracy: 0.8332
# Epoch 36/40
# 507/507 [==============================] - 136s 269ms/step - loss: 0.1513 - accuracy: 0.9424 - val_loss: 0.3803 - val_accuracy: 0.8461
# Epoch 37/40
# 507/507 [==============================] - 134s 265ms/step - loss: 0.1478 - accuracy: 0.9439 - val_loss: 0.3918 - val_accuracy: 0.8426
# Epoch 38/40
# 507/507 [==============================] - 125s 245ms/step - loss: 0.1513 - accuracy: 0.9417 - val_loss: 0.4099 - val_accuracy: 0.8358
# Epoch 39/40
# 507/507 [==============================] - 134s 264ms/step - loss: 0.1516 - accuracy: 0.9438 - val_loss: 0.4102 - val_accuracy: 0.8369
# Epoch 40/40
# 507/507 [==============================] - 125s 245ms/step - loss: 0.1440 - accuracy: 0.9463 - val_loss: 0.3873 - val_accuracy: 0.8460

# %%
plt.plot(r.history["loss"], label= "Loss")
plt.plot(r.history["val_loss"], label = "val_Loss")
plt.legend();

# %%
plt.plot(r.history["accuracy"] ,label = "Accuracy")
plt.plot(r.history["val_accuracy"] ,label = "Val_Accuracy")
plt.legend();

# %%
pd.DataFrame(r.history).to_csv("densenet.csv",index=False)

# %%
model.save("Densenet.h5")

# %% [markdown]
# ## MORE TRAINING

# %%
LR = 0.001
EPOCHS = 30

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(LR),
              loss = "binary_crossentropy",
              metrics = ["accuracy"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
modelsdir = "models"
checkpoint = ModelCheckpoint(filepath = modelsdir + "/(mt)SGD.{epoch:02d}-{val_accuracy:.4f}.h5" ,
                             monitor= "val_accuracy" , 
                             mode = "max",
                            verbose = 0,
                            save_best_only=True)

# %%
s = model.fit(train_generator , validation_data=(x_valid, y_valid), steps_per_epoch = spe ,epochs=EPOCHS, callbacks = [checkpoint])
# Out:
# Epoch 1/30
# 507/507 [==============================] - 179s 263ms/step - loss: 0.1404 - accuracy: 0.9475 - val_loss: 0.3694 - val_accuracy: 0.8551
# Epoch 2/30
# 507/507 [==============================] - 135s 265ms/step - loss: 0.1288 - accuracy: 0.9520 - val_loss: 0.4737 - val_accuracy: 0.8262
# Epoch 3/30
# 507/507 [==============================] - 134s 264ms/step - loss: 0.1168 - accuracy: 0.9553 - val_loss: 0.4518 - val_accuracy: 0.8392
# Epoch 4/30
# 507/507 [==============================] - 138s 271ms/step - loss: 0.1096 - accuracy: 0.9594 - val_loss: 0.3242 - val_accuracy: 0.8871
# Epoch 5/30
# 507/507 [==============================] - 137s 269ms/step - loss: 0.0984 - accuracy: 0.9631 - val_loss: 0.3968 - val_accuracy: 0.8656
# Epoch 6/30
# 507/507 [==============================] - 136s 267ms/step - loss: 0.0947 - accuracy: 0.9633 - val_loss: 0.4006 - val_accuracy: 0.8589
# Epoch 7/30
# 507/507 [==============================] - 135s 267ms/step - loss: 0.0854 - accuracy: 0.9700 - val_loss: 0.4685 - val_accuracy: 0.8526
# Epoch 8/30
# 507/507 [==============================] - 135s 266ms/step - loss: 0.0788 - accuracy: 0.9716 - val_loss: 0.4265 - val_accuracy: 0.8612
# Epoch 9/30
# 507/507 [==============================] - 126s 249ms/step - loss: 0.0795 - accuracy: 0.9711 - val_loss: 0.3408 - val_accuracy: 0.8885
# Epoch 10/30
# 507/507 [==============================] - 134s 265ms/step - loss: 0.0710 - accuracy: 0.9746 - val_loss: 0.4433 - val_accuracy: 0.8597
# Epoch 11/30
# 507/507 [==============================] - 134s 265ms/step - loss: 0.0681 - accuracy: 0.9743 - val_loss: 0.4010 - val_accuracy: 0.8790
# Epoch 12/30
# 507/507 [==============================] - 136s 268ms/step - loss: 0.0654 - accuracy: 0.9755 - val_loss: 0.5861 - val_accuracy: 0.8392
# Epoch 13/30
# 507/507 [==============================] - 136s 269ms/step - loss: 0.0626 - accuracy: 0.9768 - val_loss: 0.5152 - val_accuracy: 0.8538
# Epoch 14/30
# 507/507 [==============================] - 136s 267ms/step - loss: 0.0594 - accuracy: 0.9786 - val_loss: 0.4299 - val_accuracy: 0.8730
# Epoch 15/30
# 507/507 [==============================] - 126s 247ms/step - loss: 0.0575 - accuracy: 0.9797 - val_loss: 0.4045 - val_accuracy: 0.8762
# Epoch 16/30
# 507/507 [==============================] - 136s 268ms/step - loss: 0.0502 - accuracy: 0.9817 - val_loss: 0.4694 - val_accuracy: 0.8615
# Epoch 17/30
# 507/507 [==============================] - 126s 249ms/step - loss: 0.0478 - accuracy: 0.9831 - val_loss: 0.3964 - val_accuracy: 0.8871
# Epoch 18/30
# 507/507 [==============================] - 126s 248ms/step - loss: 0.0442 - accuracy: 0.9845 - val_loss: 0.4299 - val_accuracy: 0.8784
# Epoch 19/30
# 507/507 [==============================] - 128s 251ms/step - loss: 0.0457 - accuracy: 0.9845 - val_loss: 0.3761 - val_accuracy: 0.8919
# Epoch 20/30
# 507/507 [==============================] - 136s 268ms/step - loss: 0.0409 - accuracy: 0.9850 - val_loss: 0.4623 - val_accuracy: 0.8776
# Epoch 21/30
# 507/507 [==============================] - 126s 247ms/step - loss: 0.0404 - accuracy: 0.9856 - val_loss: 0.4790 - val_accuracy: 0.8763
# Epoch 22/30
# 507/507 [==============================] - 135s 266ms/step - loss: 0.0380 - accuracy: 0.9874 - val_loss: 0.5149 - val_accuracy: 0.8648
# Epoch 23/30
# 507/507 [==============================] - 127s 250ms/step - loss: 0.0379 - accuracy: 0.9882 - val_loss: 0.3251 - val_accuracy: 0.9138
# Epoch 24/30
# 507/507 [==============================] - 125s 246ms/step - loss: 0.0333 - accuracy: 0.9883 - val_loss: 0.3803 - val_accuracy: 0.8987
# Epoch 25/30
# 507/507 [==============================] - 124s 244ms/step - loss: 0.0302 - accuracy: 0.9900 - val_loss: 0.4442 - val_accuracy: 0.8893
# Epoch 26/30
# 507/507 [==============================] - 133s 263ms/step - loss: 0.0307 - accuracy: 0.9893 - val_loss: 0.3852 - val_accuracy: 0.9021
# Epoch 27/30
# 507/507 [==============================] - 134s 264ms/step - loss: 0.0317 - accuracy: 0.9882 - val_loss: 0.3510 - val_accuracy: 0.9087
# Epoch 28/30
# 507/507 [==============================] - 125s 245ms/step - loss: 0.0271 - accuracy: 0.9906 - val_loss: 0.5343 - val_accuracy: 0.8745
# Epoch 29/30
# 507/507 [==============================] - 124s 245ms/step - loss: 0.0255 - accuracy: 0.9908 - val_loss: 0.4237 - val_accuracy: 0.8953
# Epoch 30/30
# 507/507 [==============================] - 125s 245ms/step - loss: 0.0256 - accuracy: 0.9916 - val_loss: 0.3787 - val_accuracy: 0.9134

# %%
plt.plot(s.history["loss"], label= "Loss")
plt.plot(s.history["val_loss"], label = "val_Loss")
plt.legend();

# %%
plt.plot(s.history["accuracy"] ,label = "Accuracy")
plt.plot(s.history["val_accuracy"] ,label = "Val_Accuracy")
plt.legend();

# %%
pd.DataFrame(s.history).to_csv("densenet-2.csv",index=False)

# %%
model.save("Densenet-2.h5")
